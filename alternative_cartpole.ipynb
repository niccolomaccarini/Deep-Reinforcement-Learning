# %%
import random
import gym
import numpy as np
from collections import deque
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from cartpole_environment import CartPoleEnv

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 1000000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995
ENV_NAME = 'CartPole-v1'

class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=keras.optimizers.Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)


def cartpole():
    #env = gym.make(ENV_NAME)
    env = CartPoleEnv()
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            #env.render()
            action = dqn_solver.act(state)
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
                break
            dqn_solver.experience_replay()


if __name__ == "__main__":
    cartpole()
# Out:
# C:\Users\nikma\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Run: 1, exploration: 1.0, score: 16
# Run: 2, exploration: 0.946354579813443, score: 15
# Run: 3, exploration: 0.7901049725470279, score: 37
# Run: 4, exploration: 0.7477194593032545, score: 12
# Run: 5, exploration: 0.7111635524897149, score: 11
# Run: 6, exploration: 0.6662995813682115, score: 14
# Run: 7, exploration: 0.5967292370047992, score: 23
# Run: 8, exploration: 0.5590843898207511, score: 14
# Run: 9, exploration: 0.5264466124450268, score: 13
# Run: 10, exploration: 0.4858739637363176, score: 17
# Run: 11, exploration: 0.4529463432347434, score: 15
# Run: 12, exploration: 0.4286478463299511, score: 12
# Run: 13, exploration: 0.40974000909221303, score: 10
# Run: 14, exploration: 0.3877593341372176, score: 12
# Run: 15, exploration: 0.36512303261753626, score: 13
# Run: 16, exploration: 0.3472722151889232, score: 11
# Run: 17, exploration: 0.32864265128599696, score: 12
# Run: 18, exploration: 0.3125753549412418, score: 11
# Run: 19, exploration: 0.2987875242397482, score: 10
# Run: 20, exploration: 0.285607880564032, score: 10
# Run: 21, exploration: 0.2689348941735696, score: 13
# Run: 22, exploration: 0.2583638820072446, score: 9
# Run: 23, exploration: 0.2457325055235537, score: 11
# Run: 24, exploration: 0.23489314109365644, score: 10
# Run: 25, exploration: 0.22453190559909803, score: 10
# Run: 26, exploration: 0.21462770857094118, score: 10
# Run: 27, exploration: 0.2031139149609751, score: 12
# Run: 28, exploration: 0.192217783647157, score: 12
# Run: 29, exploration: 0.18373897616330553, score: 10
# Run: 30, exploration: 0.17651675623376062, score: 9
# Run: 31, exploration: 0.16704744067563246, score: 12
# Run: 32, exploration: 0.15967890763313974, score: 10
# Run: 33, exploration: 0.1518722266715875, score: 11
# Run: 34, exploration: 0.14590259167570602, score: 9
# Run: 35, exploration: 0.14016760486247823, score: 9
# Run: 36, exploration: 0.13331482894782642, score: 11
# Run: 37, exploration: 0.12807462877562611, score: 9
# Run: 38, exploration: 0.12120401149972035, score: 12
# Run: 39, exploration: 0.11643985070121858, score: 9
# Run: 40, exploration: 0.11074712159185099, score: 11
# Run: 41, exploration: 0.10586201936274783, score: 10
# Run: 42, exploration: 0.10119240105273684, score: 10
# Run: 43, exploration: 0.09770335251664321, score: 8
# Run: 44, exploration: 0.09153970651645797, score: 14
# Run: 45, exploration: 0.08364210790237678, score: 19
# Run: 46, exploration: 0.07379076075438468, score: 26
# Run: 47, exploration: 0.05830244700006734, score: 48
# Run: 48, exploration: 0.04043632488927963, score: 74
# Run: 49, exploration: 0.0280450728002803, score: 74
# Run: 50, exploration: 0.020145585821044927, score: 67
# Run: 51, exploration: 0.013763663225419333, score: 77
# Run: 52, exploration: 0.011606967888870102, score: 35
# Run: 53, exploration: 0.010036634861955105, score: 30
# Run: 54, exploration: 0.01, score: 10
# Run: 55, exploration: 0.01, score: 9
# Run: 56, exploration: 0.01, score: 9
# Run: 57, exploration: 0.01, score: 10
# Run: 58, exploration: 0.01, score: 10
# Run: 59, exploration: 0.01, score: 10
# Run: 60, exploration: 0.01, score: 10
# Run: 61, exploration: 0.01, score: 10
# Run: 62, exploration: 0.01, score: 11
# Run: 63, exploration: 0.01, score: 10
# Run: 64, exploration: 0.01, score: 10
# Run: 65, exploration: 0.01, score: 10
# Run: 66, exploration: 0.01, score: 9
# Run: 67, exploration: 0.01, score: 10
# Run: 68, exploration: 0.01, score: 10
# Run: 69, exploration: 0.01, score: 10
# Run: 70, exploration: 0.01, score: 8
# Run: 71, exploration: 0.01, score: 9
# Run: 72, exploration: 0.01, score: 10
# Run: 73, exploration: 0.01, score: 9
# Run: 74, exploration: 0.01, score: 8
# Run: 75, exploration: 0.01, score: 10
# Run: 76, exploration: 0.01, score: 10
# Run: 77, exploration: 0.01, score: 9
# Run: 78, exploration: 0.01, score: 10
# Run: 79, exploration: 0.01, score: 9
# Run: 80, exploration: 0.01, score: 10
# Run: 81, exploration: 0.01, score: 8
# Run: 82, exploration: 0.01, score: 10
# Run: 83, exploration: 0.01, score: 10
# Run: 84, exploration: 0.01, score: 10
# Run: 85, exploration: 0.01, score: 9
# Run: 86, exploration: 0.01, score: 10
# Run: 87, exploration: 0.01, score: 10
# Run: 88, exploration: 0.01, score: 10
# Run: 89, exploration: 0.01, score: 9
# Run: 90, exploration: 0.01, score: 10
# Run: 91, exploration: 0.01, score: 8
# Run: 92, exploration: 0.01, score: 10
# Run: 93, exploration: 0.01, score: 10
# Run: 94, exploration: 0.01, score: 10
# Run: 95, exploration: 0.01, score: 8
# Run: 96, exploration: 0.01, score: 10
# Run: 97, exploration: 0.01, score: 8
# Run: 98, exploration: 0.01, score: 9
# Run: 99, exploration: 0.01, score: 11
# Run: 100, exploration: 0.01, score: 10
# Run: 101, exploration: 0.01, score: 10
# Run: 102, exploration: 0.01, score: 10
# Run: 103, exploration: 0.01, score: 10
# Run: 104, exploration: 0.01, score: 10
# Run: 105, exploration: 0.01, score: 9
# Run: 106, exploration: 0.01, score: 10
# Run: 107, exploration: 0.01, score: 16
# Run: 108, exploration: 0.01, score: 10
# Run: 109, exploration: 0.01, score: 10
# Run: 110, exploration: 0.01, score: 15
# Run: 111, exploration: 0.01, score: 129
# Run: 112, exploration: 0.01, score: 15
# Run: 113, exploration: 0.01, score: 31
# Run: 114, exploration: 0.01, score: 23
# Run: 115, exploration: 0.01, score: 26
# Run: 116, exploration: 0.01, score: 31
# Run: 117, exploration: 0.01, score: 23
# Run: 118, exploration: 0.01, score: 24
# Run: 119, exploration: 0.01, score: 21
# Run: 120, exploration: 0.01, score: 26
# Run: 121, exploration: 0.01, score: 21
# Run: 122, exploration: 0.01, score: 19
# Run: 123, exploration: 0.01, score: 26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5a4ef083709e> in <module>
#      85
#      86 if __name__ == "__main__":
# ---> 87     cartpole()
#
# <ipython-input-1-5a4ef083709e> in cartpole()
#      81                 print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
#      82                 break
# ---> 83             dqn_solver.experience_replay()
#      84
#      85
#
# <ipython-input-1-5a4ef083709e> in experience_replay(self)
#      52             q_values = self.model.predict(state)
#      53             q_values[0][action] = q_update
# ---> 54             self.model.fit(state, q_values, verbose=0)
#      55         self.exploration_rate *= EXPLORATION_DECAY
#      56         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1132          training_utils.RespectCompiledTrainableState(self):
#    1133       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1134       data_handler = data_adapter.get_data_handler(
#    1135           x=x,
#    1136           y=y,
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1136
#    1137     adapter_cls = select_data_adapter(x, y)
# -> 1138     self._adapter = adapter_cls(
#    1139         x,
#    1140         y,
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     320     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     321
# --> 322     dataset = self.slice_inputs(indices_dataset, inputs)
#     323
#     324     if shuffle == "batch":
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     346     dataset = tf.data.Dataset.zip((
#     347         indices_dataset,
# --> 348         tf.data.Dataset.from_tensors(inputs).repeat()
#     349     ))
#     350
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in from_tensors(tensors)
#     604       Dataset: A `Dataset`.
#     605     """
# --> 606     return TensorDataset(tensors)
#     607
#     608   @staticmethod
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, element)
#    3827     self._tensors = structure.to_tensor_list(self._structure, element)
#    3828
# -> 3829     variant_tensor = gen_dataset_ops.tensor_dataset(
#    3830         self._tensors,
#    3831         output_shapes=structure.get_flat_tensor_shapes(self._structure))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in tensor_dataset(components, output_shapes, name)
#    7036   if tld.is_eager:
#    7037     try:
# -> 7038       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    7039         _ctx, "TensorDataset", name, components, "output_shapes",
#    7040         output_shapes)
#
# KeyboardInterrupt:
